# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
import os
import zipfile
import xlrd

# %%
g = []
with open(r'datasets/4_necessary_inn.txt', 'r') as file:
    g = file.readlines()

# %%
g
# Out:
# ['394609645484\n',
#  '281578625230\n',
#  '923769811917\n',
#  '998694734508\n',
#  '271011690615\n',
#  '924952812367\n',
#  '646685244561\n',
#  '581531230312\n',
#  '841967395801\n',
#  '962179889311\n',
#  '873191383820\n',
#  '590538076039\n',
#  '194319975048\n',
#  '614658394086\n',
#  '571270160555\n',
#  '609400911893\n',
#  '595260069852\n',
#  '706966142477\n',
#  '173050718969\n',
#  '968048428696\n',
#  '806967744814\n',
#  '575198252501\n',
#  '283081417246\n',
#  '663119569897\n',
#  '600958529354\n',
#  '280452832937\n',
#  '415557497037\n',
#  '195142638722\n',
#  '472181033836\n',
#  '722903871682\n',
#  '442387408954\n',
#  '196518820495\n',
#  '653798670054\n',
#  '126259856639\n',
#  '175482780898\n',
#  '192518356612\n',
#  '817648134701\n',
#  '321724220657\n',
#  '864970037680\n',
#  '822991191528\n',
#  '205472219644\n',
#  '532801459453\n',
#  '657038381012\n',
#  '197916669463\n',
#  '849814898285\n',
#  '617082656257\n',
#  '500480544925\n',
# ...

# %%
necessery = []
with open(r'datasets/4_necessary_inn.txt', 'r') as file:
    for line in file:
        necessery.append(line)

# %%
necessery
# Out:
# ['394609645484\n',
#  '281578625230\n',
#  '923769811917\n',
#  '998694734508\n',
#  '271011690615\n',
#  '924952812367\n',
#  '646685244561\n',
#  '581531230312\n',
#  '841967395801\n',
#  '962179889311\n',
#  '873191383820\n',
#  '590538076039\n',
#  '194319975048\n',
#  '614658394086\n',
#  '571270160555\n',
#  '609400911893\n',
#  '595260069852\n',
#  '706966142477\n',
#  '173050718969\n',
#  '968048428696\n',
#  '806967744814\n',
#  '575198252501\n',
#  '283081417246\n',
#  '663119569897\n',
#  '600958529354\n',
#  '280452832937\n',
#  '415557497037\n',
#  '195142638722\n',
#  '472181033836\n',
#  '722903871682\n',
#  '442387408954\n',
#  '196518820495\n',
#  '653798670054\n',
#  '126259856639\n',
#  '175482780898\n',
#  '192518356612\n',
#  '817648134701\n',
#  '321724220657\n',
#  '864970037680\n',
#  '822991191528\n',
#  '205472219644\n',
#  '532801459453\n',
#  '657038381012\n',
#  '197916669463\n',
#  '849814898285\n',
#  '617082656257\n',
#  '500480544925\n',
# ...

# %%
necessery = [line.strip() for line in necessery]
necessery = [int(x) for x in necessery]

# %%
necessery
# Out:
# [394609645484,
#  281578625230,
#  923769811917,
#  998694734508,
#  271011690615,
#  924952812367,
#  646685244561,
#  581531230312,
#  841967395801,
#  962179889311,
#  873191383820,
#  590538076039,
#  194319975048,
#  614658394086,
#  571270160555,
#  609400911893,
#  595260069852,
#  706966142477,
#  173050718969,
#  968048428696,
#  806967744814,
#  575198252501,
#  283081417246,
#  663119569897,
#  600958529354,
#  280452832937,
#  415557497037,
#  195142638722,
#  472181033836,
#  722903871682,
#  442387408954,
#  196518820495,
#  653798670054,
#  126259856639,
#  175482780898,
#  192518356612,
#  817648134701,
#  321724220657,
#  864970037680,
#  822991191528,
#  205472219644,
#  532801459453,
#  657038381012,
#  197916669463,
#  849814898285,
#  617082656257,
#  500480544925,
#  765833725639,
#  263518962896,
#  415856290529,
#  812729265571,
#  688172366656,
#  837771137752,
#  456294893364,
#  668157292633,
#  491435460276,
#  323896131459,
#  664667769879,
# ...

# %%
len(necessery)
# Out:
# 115

# %%
data = pd.read_excel(r'datasets/4_inn.xls', index_col='#')

# %%
data.head()
# Out:
#    Unnamed: 0                                    name     reg_number  \
# #
# 0           0         ЗАО «Власова, Макаров и Шашков»  1143692580560
# 1           1  РАО «Тимофеева, Алексеева и Кузнецова»  9342309660697
# 2           2                      РАО «Юдин-Ефимова»  1277485323451
# 3           3                   Доронин Инкорпорэйтед  7139161431511
# 4           4    Объединенная энергетическая компания  6114798049639
#
#                                              address  \
# #
# 0  д. Кирово-Чепецк, пр. Металлургов, д. 537 к. 3...
# 1  г. Арзамас, наб. Фестивальная, д. 7 стр. 8/2, ...
# 2  п. Меренга, алл. Достоевского, д. 3/4 к. 497, ...
# 3  д. Иваново, ул. Красных Партизан, д. 83 к. 4, ...
# 4           к. Энгельс, наб. Шишкина, д. 120, 823828
#
#                           head              head_job      head_inn  \
# #
# 0        Жданов Карл Виленович              Маммолог  109092209811
# 1  Рожков Харлампий Алексеевич           Воспитатель  704229465069
# ...

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
true_data =  data.loc[data.head_inn.isin(necessery)]

# %%
true_data
# Out:
#                                     name     reg_number  \
# #
# 47                        Пермэнергосбыт  6417532956774
# 76                ЗАО «Кабанова Ковалев»  9343329412518
# 77                               Неофарм  3813743111150
# 85                           Арконик СМЗ  7465966885549
# 90                       Фармперспектива  6205521489390
# ...                                  ...            ...
# 2059    ЗАО «Кабанова, Титов и Бирюкова»  4405157155853
# 2074  ООО «Фомин, Симонова и Никифорова»  9213736030860
# 2089                  НПО «Зимин Иванов»  6791957421599
# 2106                           Юдина Лтд  5012825137426
# 2108                ООО «Хохлов Казаков»  9506828156265
#
#                                                 address  \
# #
# 47    ст. Слюдянка, пер. Брянский, д. 378 стр. 634, ...
# 76       с. Нарткала, ул. Верхняя, д. 68 стр. 1, 393309
# 77        г. Долинск, ш. Московское, д. 25 к. 5, 227970
# ...

# %%
true_data.shape
# Out:
# (115, 18)

# %%
true_data.to_csv('selected_inn.csv', index=False)

# %%
int(true_data['income,RUB'].sum())
# Out:
# 6104522627393
